# %% [markdown]
# <a href="https://colab.research.google.com/github/szsavery/DSPS_SSavery/blob/main/Bayesian_posteriors_Savery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Do priors matter??

# %% [markdown]
# Inspired by https://twitter.com/rlmcelreath/status/1701165078949581182/photo/1
#
# Use `scipy.stats` to generate four distributions:
# - a standard normal with mean 0, variance 1
# - a standard normal with mean 10, variance 1
# - a student's with 2 degrees of freedom centered on 0
# - a student's with 2 degrees of freedom centered on 10
#
# Plot all the distributions
#
#
# Create a function that takes a prior, a likelihood as arguments and plots the prior, likelihood, and posterior (normalize each so that the peak is at the same height for optimal visibility)
#
# Pass to the function each combination of prior and likelihood between the four distributions you created: normal-normal, t-t, normal-t, t-normal

# %%
#these are all the imports you need
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

print('Done')
# Out:
# Done

# %%
#First distribution
#Normal distribution with mean 0

x = np.linspace(-5, 15, 1000)

y1 = stats.norm.pdf(x, loc = 0, scale = 1.0)
plt.plot(x,y1, label = 'Normal, mean = 0')
plt.legend()
plt.show()

# %%
#Second distribution
#Normal distribution with mean = 10

y2 = stats.norm.pdf(x, loc = 10, scale = 1.0)
plt.plot(x,y2, label = 'Normal, mean = 10')
plt.legend()
plt.show()

# %%
#Student's t distribution centered on 0

y3 = stats.t.pdf(x, df = 2, loc = 0, scale = 1.0)

plt.plot(x, y3, label = 'Student, centered on 0')
plt.legend()
plt.show()

# %%
#Student's t distribution centered on 10

y4 = stats.t.pdf(x,df = 2, loc = 10, scale = 1.0)

plt.plot(x,y4, label = 'Student, centered on 10')
plt.legend()
plt.show()

# %%
def posterior(p, l):
  combined = p*l
  plt.plot(x, p/p.max(), 'k.--', markersize = '0.5', label = 'prior')
  plt.plot(x, l/l.max(), 'g.--', markersize = '0.5', label = 'likeilhood')
  plt.plot(x, combined/combined.max(), 'b', label = 'posterior')
  plt.legend()
  plt.show()

# %% [markdown]
# The needed combinations for posteriors are $y1*y2, y1*y3, y1*y4, y2*y1, y2*y3, y2*y4, y3*y1, y3*y2, y3*y4, y4*y1, y4*y2, y4*y3$.

# %%
posterior(y1,y2)

# %%
posterior(y1,y3)

# %%
posterior(y1,y4)

# %%
posterior(y2,y1)

# %%
posterior(y2,y3)

# %%
posterior(y2,y4)

# %%
posterior(y3,y1)

# %%
posterior(y3,y2)

# %%
posterior(y3,y4)

# %%
posterior(y4,y1)

# %%
posterior(y4,y2)

# %%
posterior(y4,y3)
